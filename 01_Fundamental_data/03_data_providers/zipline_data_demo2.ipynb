# %% [markdown]
# # Data Access with Zipline

# %% [markdown]
# Zipline is the algorithmic trading library that used to power the now-defunct Quantopian backtesting and live-trading platform. It is also available offline to develop a strategy using a limited number of free data bundles that can be ingested and used to test the performance of trading ideas.

# %% [markdown]
# ## Zipline installation

# %% [markdown]
# > This notebook requires the `conda` environment `backtest`. Please see the [installation instructions](../installation/README.md) for running the latest Docker image or alternative ways to set up your environment.

# %% [markdown]
# There is much more information about Zipline in [Chapter 8](../../08_ml4t_workflow/04_ml4t_workflow_with_zipline).

# %% [markdown]
# ## Imports & Settings

# %%
# %matplotlib inline
import pandas as pd

# %%
# %load_ext zipline

# %% [markdown]
# ## zipline Demo

# %% [markdown]
# ### Ingest Data

# %% [markdown]
# Get QUANDL API key and follow instructions to download zipline bundles [here](https://zipline.ml4trading.io/bundles.html). This boils down to running:

# %%
# !zipline ingest

# %% [markdown]
# See `zipline` [docs](https://zipline.ml4trading.io/bundles.html) on the download and management of data bundles used to simulate backtests.
#
# The following commandline instruction lists the available bundles (store per default in `~/.zipline`.

# %%
# !zipline bundles

# %% [markdown]
# ### Data access using zipline

# %% [markdown]
# The following code illustrates how zipline permits us to access daily stock data for a range of companies. You can run zipline scripts in the Jupyter Notebook using the magic function of the same name.

# %% [markdown]
# First, you need to initialize the context with the desired security symbols. We'll also use a counter variable. Then zipline calls handle_data, where we use the `data.history()` method to look back a single period and append the data for the last day to a .csv file:

# %%
# %%zipline --start 2010-1-1 --end 2018-1-1 --data-frequency daily --no-benchmark
# from zipline.api import order_target, record, symbol
# import pandas as pd
#
# def initialize(context):
#     context.i = 0
#     context.assets = [symbol('AAPL'), symbol('GOOG'), symbol('AMZN')]
#
# def handle_data(context, data):
#     df = data.history(context.assets, fields=['price', 'volume'], bar_count=1, frequency="1d")
#     df = df.reset_index()
#
#     if context.i == 0:
#         df.columns = ['date', 'asset', 'price', 'volume']
#         df.to_csv('stock_data.csv', index=False)
#     else:
#         df.to_csv('stock_data.csv', index=False, mode='a', header=None)
#     context.i += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/memoize.py:56, in lazyval.__get__(self, instance, owner)
#      55 try:
# ---> 56     return self._cache[instance]
#      57 except KeyError:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/weakref.py:383, in WeakKeyDictionary.__getitem__(self, key)
#     382 def __getitem__(self, key):
# --> 383     return self.data[ref(key)]
#
# KeyError: <weakref at 0x120e6b720; to 'BcolzMinuteBarReader' at 0x120e79dc0>
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2010-1-1 --end 2018-1-1 --data-frequency daily --no-benchmark', 'from zipline.api import order_target, record, symbol\nimport pandas as pd\n\ndef initialize(context):\n    context.i = 0\n    context.assets = [symbol(\'AAPL\'), symbol(\'GOOG\'), symbol(\'AMZN\')]\n    \ndef handle_data(context, data):\n    df = data.history(context.assets, fields=[\'price\', \'volume\'], bar_count=1, frequency="1d")\n    df = df.reset_index()\n    \n    if context.i == 0:\n        df.columns = [\'date\', \'asset\', \'price\', \'volume\']\n        df.to_csv(\'stock_data.csv\', index=False)\n    else:\n        df.to_csv(\'stock_data.csv\', index=False, mode=\'a\', header=None)\n    context.i += 1\n')
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2430, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2428 with self.builtin_trap:
#    2429     args = (magic_arg_s, cell)
# -> 2430     result = fn(*args, **kwargs)
#    2432 # The code below prevents the output from being displayed
#    2433 # when using magics with decodator @output_can_be_silenced
#    2434 # when the last Python token in the expression is a ';'.
#    2435 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/__main__.py:335, in zipline_magic(line, cell)
#     328 load_extensions(
#     329     default=True,
#     330     extensions=[],
#     331     strict=True,
#     332     environ=os.environ,
#     333 )
#     334 try:
# --> 335     return run.main(
#     336         # put our overrides at the start of the parameter list so that
#     337         # users may pass values with higher precedence
#     338         [
#     339             "--algotext",
#     340             cell,
#     341             "--output",
#     342             os.devnull,  # don't write the results by default
#     343         ]
#     344         + (
#     345             [
#     346                 # these options are set when running in line magic mode
#     347                 # set a non None algo text to use the ipython user_ns
#     348                 "--algotext",
#     349                 "",
#     350                 "--local-namespace",
#     351             ]
#     352             if cell is None
#     353             else []
#     354         )
#     355         + line.split(),
#     356         "%s%%zipline" % ((cell or "") and "%"),
#     357         # don't use system exit and propogate errors to the caller
#     358         standalone_mode=False,
#     359     )
#     360 except SystemExit as e:
#     361     # https://github.com/mitsuhiko/click/pull/533
#     362     # even in standalone_mode=False `--help` really wants to kill us ;_;
#     363     if e.code:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:1055, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1053 try:
#    1054     with self.make_context(prog_name, args, **extra) as ctx:
# -> 1055         rv = self.invoke(ctx)
#    1056         if not standalone_mode:
#    1057             return rv
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:1404, in Command.invoke(self, ctx)
#    1401     echo(style(message, fg="red"), err=True)
#    1403 if self.callback is not None:
# -> 1404     return ctx.invoke(self.callback, **ctx.params)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:760, in Context.invoke(_Context__self, _Context__callback, *args, **kwargs)
#     758 with augment_usage_errors(__self):
#     759     with ctx:
# --> 760         return __callback(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/decorators.py:26, in pass_context.<locals>.new_func(*args, **kwargs)
#      25 def new_func(*args, **kwargs):  # type: ignore
# ---> 26     return f(get_current_context(), *args, **kwargs)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/__main__.py:300, in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, benchmark_file, benchmark_symbol, benchmark_sid, no_benchmark, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, blotter)
#     291 trading_calendar = get_calendar(trading_calendar)
#     293 benchmark_spec = BenchmarkSpec.from_cli_params(
#     294     no_benchmark=no_benchmark,
#     295     benchmark_sid=benchmark_sid,
#     296     benchmark_symbol=benchmark_symbol,
#     297     benchmark_file=benchmark_file,
#     298 )
# --> 300 return _run(
#     301     initialize=None,
#     302     handle_data=None,
#     303     before_trading_start=None,
#     304     analyze=None,
#     305     algofile=algofile,
#     306     algotext=algotext,
#     307     defines=define,
#     308     data_frequency=data_frequency,
#     309     capital_base=capital_base,
#     310     bundle=bundle,
#     311     bundle_timestamp=bundle_timestamp,
#     312     start=start,
#     313     end=end,
#     314     output=output,
#     315     trading_calendar=trading_calendar,
#     316     print_algo=print_algo,
#     317     metrics_set=metrics_set,
#     318     local_namespace=local_namespace,
#     319     environ=os.environ,
#     320     blotter=blotter,
#     321     benchmark_spec=benchmark_spec,
#     322     custom_loader=None,
#     323 )
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/run_algo.py:163, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#     159         click.echo(algotext)
#     161 first_trading_day = bundle_data.equity_minute_bar_reader.first_trading_day
# --> 163 data = DataPortal(
#     164     bundle_data.asset_finder,
#     165     trading_calendar=trading_calendar,
#     166     first_trading_day=first_trading_day,
#     167     equity_minute_reader=bundle_data.equity_minute_bar_reader,
#     168     equity_daily_reader=bundle_data.equity_daily_bar_reader,
#     169     adjustment_reader=bundle_data.adjustment_reader,
#     170     future_minute_reader=bundle_data.equity_minute_bar_reader,
#     171     future_daily_reader=bundle_data.equity_daily_bar_reader,
#     172 )
#     174 pipeline_loader = USEquityPricingLoader.without_fx(
#     175     bundle_data.equity_daily_bar_reader,
#     176     bundle_data.adjustment_reader,
#     177 )
#     179 def choose_loader(column):
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/data_portal.py:183, in DataPortal.__init__(self, asset_finder, trading_calendar, first_trading_day, equity_daily_reader, equity_minute_reader, future_daily_reader, future_minute_reader, adjustment_reader, last_available_session, last_available_minute, minute_history_prefetch_length, daily_history_prefetch_length)
#     180     self._last_available_minute = last_available_minute
#     181 else:
#     182     # Infer the last minute from the provided readers.
# --> 183     last_minutes = [
#     184         reader.last_available_dt
#     185         for reader in [equity_minute_reader, future_minute_reader]
#     186         if reader is not None
#     187     ]
#     188     if last_minutes:
#     189         self._last_available_minute = max(last_minutes)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/data_portal.py:184, in <listcomp>(.0)
#     180     self._last_available_minute = last_available_minute
#     181 else:
#     182     # Infer the last minute from the provided readers.
#     183     last_minutes = [
# --> 184         reader.last_available_dt
#     185         for reader in [equity_minute_reader, future_minute_reader]
#     186         if reader is not None
#     187     ]
#     188     if last_minutes:
#     189         self._last_available_minute = max(last_minutes)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/memoize.py:58, in lazyval.__get__(self, instance, owner)
#      56     return self._cache[instance]
#      57 except KeyError:
# ---> 58     self._cache[instance] = val = self.func(instance)
#      59     return val
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/minute_bars.py:953, in BcolzMinuteBarReader.last_available_dt(self)
#     951 @lazyval
#     952 def last_available_dt(self):
# --> 953     _, close = self.calendar.open_and_close_for_session(self._end_session)
#     954     return close
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/exchange_calendar.py:1080, in ExchangeCalendar.open_and_close_for_session(self, session_label)
#    1063 def open_and_close_for_session(
#    1064     self, session_label: Session
#    1065 ) -> tuple(pd.Timestamp, pd.Timestamp):
#    1066     """
#    1067     Returns a tuple of timestamps of the open and close of the session
#    1068     represented by the given label.
#    (...)
#    1078         The open and close for the given session.
#    1079     """
# -> 1080     session_label = parse_session(self, session_label, "session_label")
#    1081     return (
#    1082         self.session_open(session_label),
#    1083         self.session_close(session_label),
#    1084     )
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/calendar_helpers.py:273, in parse_session(calendar, session, param_name)
#     241 def parse_session(
#     242     calendar: ExchangeCalendar, session: Session, param_name: str
#     243 ) -> pd.Timestamp:
#     244     """Parse input intended to represent a session label.
#     245
#     246     Parameters
#    (...)
#     271         represent a session of `calendar`.
#     272     """
# --> 273     ts = parse_date(session, param_name)
#     274     # don't check via is_session to allow for more specific error message if
#     275     # `session` is out-of-bounds
#     276     if ts not in calendar.schedule.index:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/calendar_helpers.py:217, in parse_date(date, param_name, raise_oob, calendar)
#     176 """Parse input intended to represent a date.
#     177
#     178  Parameters
#    (...)
#     213     `calendar`'s last session.
#     214 """
#     215 ts = parse_timestamp(date, param_name, utc=False)
# --> 217 if not (ts.tz is None or ts.tz.zone == "UTC"):
#     218     raise ValueError(
#     219         f"Parameter `{param_name}` parsed as '{ts}' although a Date must be"
#     220         f" timezone naive or have timezone as 'UTC'."
#     221     )
#     223 if not ts == ts.normalize():
#
# AttributeError: 'datetime.timezone' object has no attribute 'zone'

# %% [markdown]
# We can plot the data as follows:

# %%
df = pd.read_csv('stock_data.csv')
df.date = pd.to_datetime(df.date)
df.set_index('date').groupby('asset').price.plot(lw=2, legend=True, figsize=(14, 6))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('stock_data.csv')
#       2 df.date = pd.to_datetime(df.date)
#       3 df.set_index('date').groupby('asset').price.plot(lw=2, legend=True, figsize=(14, 6))
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stock_data.csv'

# %% [markdown]
# ### Simple moving average strategy

# %% [markdown]
# The following code example illustrates a [Dual Moving Average Cross-Over Strategy](https://zipline.ml4trading.io/beginner-tutorial.html#access-to-previous-prices-using-history) to demonstrate Zipline in action:

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig, (ax1, ax2) = plt.subplots(nrows=2,figsize=(14, 8))
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/memoize.py:56, in lazyval.__get__(self, instance, owner)
#      55 try:
# ---> 56     return self._cache[instance]
#      57 except KeyError:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/weakref.py:383, in WeakKeyDictionary.__getitem__(self, key)
#     382 def __getitem__(self, key):
# --> 383     return self.data[ref(key)]
#
# KeyError: <weakref at 0x120407360; to 'BcolzMinuteBarReader' at 0x115e98f10>
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle', 'from zipline.api import order_target, record, symbol\nimport matplotlib.pyplot as plt\n\ndef initialize(context):\n    context.i = 0\n    context.asset = symbol(\'AAPL\')\n\n\ndef handle_data(context, data):\n    # Skip first 300 days to get full windows\n    context.i += 1\n    if context.i < 300:\n        return\n\n    # Compute averages\n    # data.history() has to be called with the same params\n    # from above and returns a pandas dataframe.\n    short_mavg = data.history(context.asset, \'price\', bar_count=100, frequency="1d").mean()\n    long_mavg = data.history(context.asset, \'price\', bar_count=300, frequency="1d").mean()\n\n    # Trading logic\n    if short_mavg > long_mavg:\n        # order_target orders as many shares as needed to\n        # achieve the desired number of shares.\n        order_target(context.asset, 100)\n    elif short_mavg < long_mavg:\n        order_target(context.asset, 0)\n\n    # Save values for later inspection\n    record(AAPL=data.current(context.asset, \'price\'),\n           short_mavg=short_mavg,\n           long_mavg=long_mavg)\n\n\ndef analyze(context, perf):\n    fig, (ax1, ax2) = plt.subplots(nrows=2,figsize=(14, 8))\n    perf.portfolio_value.plot(ax=ax1)\n    ax1.set_ylabel(\'portfolio value in $\')\n\n    perf[\'AAPL\'].plot(ax=ax2)\n    perf[[\'short_mavg\', \'long_mavg\']].plot(ax=ax2)\n\n    perf_trans = perf.loc[[t != [] for t in perf.transactions]]\n    buys = perf_trans.loc[[t[0][\'amount\'] > 0 for t in perf_trans.transactions]]\n    sells = perf_trans.loc[\n        [t[0][\'amount\'] < 0 for t in perf_trans.transactions]]\n    ax2.plot(buys.index, perf.short_mavg.loc[buys.index],\n             \'^\', markersize=10, color=\'m\')\n    ax2.plot(sells.index, perf.short_mavg.loc[sells.index],\n             \'v\', markersize=10, color=\'k\')\n    ax2.set_ylabel(\'price in $\')\n    plt.legend(loc=0)\n    plt.show() \n')
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2430, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2428 with self.builtin_trap:
#    2429     args = (magic_arg_s, cell)
# -> 2430     result = fn(*args, **kwargs)
#    2432 # The code below prevents the output from being displayed
#    2433 # when using magics with decodator @output_can_be_silenced
#    2434 # when the last Python token in the expression is a ';'.
#    2435 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/__main__.py:335, in zipline_magic(line, cell)
#     328 load_extensions(
#     329     default=True,
#     330     extensions=[],
#     331     strict=True,
#     332     environ=os.environ,
#     333 )
#     334 try:
# --> 335     return run.main(
#     336         # put our overrides at the start of the parameter list so that
#     337         # users may pass values with higher precedence
#     338         [
#     339             "--algotext",
#     340             cell,
#     341             "--output",
#     342             os.devnull,  # don't write the results by default
#     343         ]
#     344         + (
#     345             [
#     346                 # these options are set when running in line magic mode
#     347                 # set a non None algo text to use the ipython user_ns
#     348                 "--algotext",
#     349                 "",
#     350                 "--local-namespace",
#     351             ]
#     352             if cell is None
#     353             else []
#     354         )
#     355         + line.split(),
#     356         "%s%%zipline" % ((cell or "") and "%"),
#     357         # don't use system exit and propogate errors to the caller
#     358         standalone_mode=False,
#     359     )
#     360 except SystemExit as e:
#     361     # https://github.com/mitsuhiko/click/pull/533
#     362     # even in standalone_mode=False `--help` really wants to kill us ;_;
#     363     if e.code:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:1055, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1053 try:
#    1054     with self.make_context(prog_name, args, **extra) as ctx:
# -> 1055         rv = self.invoke(ctx)
#    1056         if not standalone_mode:
#    1057             return rv
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:1404, in Command.invoke(self, ctx)
#    1401     echo(style(message, fg="red"), err=True)
#    1403 if self.callback is not None:
# -> 1404     return ctx.invoke(self.callback, **ctx.params)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/core.py:760, in Context.invoke(_Context__self, _Context__callback, *args, **kwargs)
#     758 with augment_usage_errors(__self):
#     759     with ctx:
# --> 760         return __callback(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/click/decorators.py:26, in pass_context.<locals>.new_func(*args, **kwargs)
#      25 def new_func(*args, **kwargs):  # type: ignore
# ---> 26     return f(get_current_context(), *args, **kwargs)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/__main__.py:300, in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, benchmark_file, benchmark_symbol, benchmark_sid, no_benchmark, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, blotter)
#     291 trading_calendar = get_calendar(trading_calendar)
#     293 benchmark_spec = BenchmarkSpec.from_cli_params(
#     294     no_benchmark=no_benchmark,
#     295     benchmark_sid=benchmark_sid,
#     296     benchmark_symbol=benchmark_symbol,
#     297     benchmark_file=benchmark_file,
#     298 )
# --> 300 return _run(
#     301     initialize=None,
#     302     handle_data=None,
#     303     before_trading_start=None,
#     304     analyze=None,
#     305     algofile=algofile,
#     306     algotext=algotext,
#     307     defines=define,
#     308     data_frequency=data_frequency,
#     309     capital_base=capital_base,
#     310     bundle=bundle,
#     311     bundle_timestamp=bundle_timestamp,
#     312     start=start,
#     313     end=end,
#     314     output=output,
#     315     trading_calendar=trading_calendar,
#     316     print_algo=print_algo,
#     317     metrics_set=metrics_set,
#     318     local_namespace=local_namespace,
#     319     environ=os.environ,
#     320     blotter=blotter,
#     321     benchmark_spec=benchmark_spec,
#     322     custom_loader=None,
#     323 )
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/run_algo.py:163, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#     159         click.echo(algotext)
#     161 first_trading_day = bundle_data.equity_minute_bar_reader.first_trading_day
# --> 163 data = DataPortal(
#     164     bundle_data.asset_finder,
#     165     trading_calendar=trading_calendar,
#     166     first_trading_day=first_trading_day,
#     167     equity_minute_reader=bundle_data.equity_minute_bar_reader,
#     168     equity_daily_reader=bundle_data.equity_daily_bar_reader,
#     169     adjustment_reader=bundle_data.adjustment_reader,
#     170     future_minute_reader=bundle_data.equity_minute_bar_reader,
#     171     future_daily_reader=bundle_data.equity_daily_bar_reader,
#     172 )
#     174 pipeline_loader = USEquityPricingLoader.without_fx(
#     175     bundle_data.equity_daily_bar_reader,
#     176     bundle_data.adjustment_reader,
#     177 )
#     179 def choose_loader(column):
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/data_portal.py:183, in DataPortal.__init__(self, asset_finder, trading_calendar, first_trading_day, equity_daily_reader, equity_minute_reader, future_daily_reader, future_minute_reader, adjustment_reader, last_available_session, last_available_minute, minute_history_prefetch_length, daily_history_prefetch_length)
#     180     self._last_available_minute = last_available_minute
#     181 else:
#     182     # Infer the last minute from the provided readers.
# --> 183     last_minutes = [
#     184         reader.last_available_dt
#     185         for reader in [equity_minute_reader, future_minute_reader]
#     186         if reader is not None
#     187     ]
#     188     if last_minutes:
#     189         self._last_available_minute = max(last_minutes)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/data_portal.py:184, in <listcomp>(.0)
#     180     self._last_available_minute = last_available_minute
#     181 else:
#     182     # Infer the last minute from the provided readers.
#     183     last_minutes = [
# --> 184         reader.last_available_dt
#     185         for reader in [equity_minute_reader, future_minute_reader]
#     186         if reader is not None
#     187     ]
#     188     if last_minutes:
#     189         self._last_available_minute = max(last_minutes)
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/utils/memoize.py:58, in lazyval.__get__(self, instance, owner)
#      56     return self._cache[instance]
#      57 except KeyError:
# ---> 58     self._cache[instance] = val = self.func(instance)
#      59     return val
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/zipline/data/minute_bars.py:953, in BcolzMinuteBarReader.last_available_dt(self)
#     951 @lazyval
#     952 def last_available_dt(self):
# --> 953     _, close = self.calendar.open_and_close_for_session(self._end_session)
#     954     return close
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/exchange_calendar.py:1080, in ExchangeCalendar.open_and_close_for_session(self, session_label)
#    1063 def open_and_close_for_session(
#    1064     self, session_label: Session
#    1065 ) -> tuple(pd.Timestamp, pd.Timestamp):
#    1066     """
#    1067     Returns a tuple of timestamps of the open and close of the session
#    1068     represented by the given label.
#    (...)
#    1078         The open and close for the given session.
#    1079     """
# -> 1080     session_label = parse_session(self, session_label, "session_label")
#    1081     return (
#    1082         self.session_open(session_label),
#    1083         self.session_close(session_label),
#    1084     )
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/calendar_helpers.py:273, in parse_session(calendar, session, param_name)
#     241 def parse_session(
#     242     calendar: ExchangeCalendar, session: Session, param_name: str
#     243 ) -> pd.Timestamp:
#     244     """Parse input intended to represent a session label.
#     245
#     246     Parameters
#    (...)
#     271         represent a session of `calendar`.
#     272     """
# --> 273     ts = parse_date(session, param_name)
#     274     # don't check via is_session to allow for more specific error message if
#     275     # `session` is out-of-bounds
#     276     if ts not in calendar.schedule.index:
#
# File ~/opt/anaconda3/envs/env_zipline/lib/python3.8/site-packages/exchange_calendars/calendar_helpers.py:217, in parse_date(date, param_name, raise_oob, calendar)
#     176 """Parse input intended to represent a date.
#     177
#     178  Parameters
#    (...)
#     213     `calendar`'s last session.
#     214 """
#     215 ts = parse_timestamp(date, param_name, utc=False)
# --> 217 if not (ts.tz is None or ts.tz.zone == "UTC"):
#     218     raise ValueError(
#     219         f"Parameter `{param_name}` parsed as '{ts}' although a Date must be"
#     220         f" timezone naive or have timezone as 'UTC'."
#     221     )
#     223 if not ts == ts.normalize():
#
# AttributeError: 'datetime.timezone' object has no attribute 'zone'
