# %%
import os
import pandas as pd
from datetime import datetime
import pandas_datareader.data as web
import pandas_datareader.famafrench as ff
import pandas_datareader.wb as wb
import yfinance as yf
from pandasdatareader import get_yahoo_data
from pandasdatareader import get_sp500_constituents
from pandasdatareader import get_quandl_data
from pandasdatareader import get_wb_data
from pandasdatareader import get_oecd_data
from pandasdatareader import get_fred_data
from pandasdatareader import get_stooq_data
from pandasdatareader import get_symbols

# %%
# pandas-datareader for Market Data
# Yahoo Finance
data = get_yahoo_data('AMZN', '2022-01-01', '2022-12-31')
data.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2022-01-03 to 2022-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       251 non-null    float64
#  1   High       251 non-null    float64
#  2   Low        251 non-null    float64
#  3   Close      251 non-null    float64
#  4   Adj Close  251 non-null    float64
#  5   Volume     251 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB

# %%
#Download html table with SP500 constituents
sp500_constituents = get_sp500_constituents()

# %%
sp500_constituents.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry
# 0    MMM           3M             Industrials        Industrial Conglomerates  \
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
#Data read through Quandl
quandl_data = get_quandl_data('FB.US', '2015-01-01')
quandl_data
# Out:
#               Open      High      Low    Close       Volume  ExDividend
# Date
# 2018-03-27  156.31  162.8500  150.750  152.190   76787884.0         0.0  \
# 2018-03-26  160.82  161.1000  149.020  160.060  125438294.0         0.0
# 2018-03-23  165.44  167.1000  159.020  159.390   52306891.0         0.0
# 2018-03-22  166.13  170.2700  163.720  164.890   73389988.0         0.0
# 2018-03-21  164.80  173.4000  163.300  169.390  105350867.0         0.0
# ...            ...       ...      ...      ...          ...         ...
# 2015-01-08   76.74   78.2300   76.080   78.175   23960953.0         0.0
# 2015-01-07   76.76   77.3600   75.820   76.150   22045333.0         0.0
# 2015-01-06   77.23   77.5900   75.365   76.150   27399288.0         0.0
# 2015-01-05   77.98   79.2455   76.860   77.190   26452191.0         0.0
# 2015-01-02   78.58   78.9300   77.700   78.450   18177475.0         0.0
#
#             SplitRatio  AdjOpen   AdjHigh   AdjLow  AdjClose    AdjVolume
# Date
# ...

# %%
#FRED
fred_data = get_fred_data('GDP', datetime(2010, 1, 1), datetime(2013, 1, 27))
wb_data = get_wb_data('NY.GDP.PCAP.KD', ['US', 'CA', 'MX'], 1990, 2019)
oecd_data = get_oecd_data('TUD', '2010', '2019')

# %%
fred_data
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.611
# 2010-04-01  14980.193
# 2010-07-01  15141.605
# 2010-10-01  15309.471
# 2011-01-01  15351.444
# 2011-04-01  15557.535
# 2011-07-01  15647.681
# 2011-10-01  15842.267
# 2012-01-01  16068.824
# 2012-04-01  16207.130
# 2012-07-01  16319.540
# 2012-10-01  16420.386
# 2013-01-01  16629.050

# %%
wb_data
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2019    45113.066282
#               2018    44917.483728
#               2017    44325.488337
#               2016    43536.913403
#               2015    43596.135537
# ...                            ...
# United States 1994    41215.342931
#               1993    40108.008037
#               1992    39552.021878
#               1991    38739.798321
#               1990    39303.489009
#
# [90 rows x 1 columns]

# %%
#OECD data
oecd_data
# Out:
# Country                  Australia                 Austria
# Frequency                   Annual                  Annual
# Measure    Percentage of employees Percentage of employees
# Time
# 2010-01-01               18.400000               28.900000  \
# 2011-01-01               18.400000               28.299999
# 2012-01-01               18.200001               28.000000
# 2013-01-01               17.000000               27.799999
# 2014-01-01               15.100000               27.700001
# 2015-01-01               14.600000               26.900000
# 2016-01-01               13.700000               26.299999
# 2017-01-01                     NaN               27.400000
# 2018-01-01                     NaN               26.700001
# 2019-01-01                     NaN               26.299999
#
# Country                    Belgium                  Canada
# Frequency                   Annual                  Annual
# Measure    Percentage of employees Percentage of employees
# Time
# ...

# %%
#Stooq
data = get_stooq_data('^SPX')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2023-07-03 to 2018-07-05
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   float64
# dtypes: float64(5)
# memory usage: 58.9 KB
